# %%
import pandas as pd

# %%
df = pd.read_json(path_or_buf="part1.json", typ="frame")

# %%
df.head(2)
# Out:
#    all_rating  all_rating_count          app_name                 bundle_id  \
# 0         5.0                 2      ! Insta-Face     bytesinarow.instaface
# 1         0.0                 0  ! Insta-Face Pro  bytesinarow.instafacepro
#
#   content_rating    downloads file_size   genre  \
# 0   Low Maturity  500 - 1,000      364k  Social
# 1       Everyone        1 - 5      888k  Social
#
#                                             icon_url  \
# 0  https://lh6.ggpht.com/tLAk2kdsvWf22tEdsFHrN-Kv...
# 1  https://lh3.ggpht.com/cdJqCdM6ymrFHE69JxglBm9p...
#
#                          id  price
# 0     bytesinarow.instaface   Free
# 1  bytesinarow.instafacepro  $0.99

# %%
df1 = df.copy()

# %%
df1.head(2)
# Out:
#    all_rating  all_rating_count          app_name                 bundle_id  \
# 0         5.0                 2      ! Insta-Face     bytesinarow.instaface
# 1         0.0                 0  ! Insta-Face Pro  bytesinarow.instafacepro
#
#   content_rating    downloads file_size   genre  \
# 0   Low Maturity  500 - 1,000      364k  Social
# 1       Everyone        1 - 5      888k  Social
#
#                                             icon_url  \
# 0  https://lh6.ggpht.com/tLAk2kdsvWf22tEdsFHrN-Kv...
# 1  https://lh3.ggpht.com/cdJqCdM6ymrFHE69JxglBm9p...
#
#                          id  price
# 0     bytesinarow.instaface   Free
# 1  bytesinarow.instafacepro  $0.99

# %%
import string

# %% [markdown]
# Removing Dollar Sign from the field 'Price'

# %%
def removedollar(x):
    tempstring=str(x)
    if str(x)=="Free":
        tempstring=float("0")
    elif str(x).startswith("$"):
        tempstring1=str(x).lstrip("$")
        tempstring=float(tempstring1)
    return float(tempstring)

# %%
df1["price1"]=df1["price"].apply (lambda x: removedollar(str(x)))

# %%
df1.head(3)
# Out:
#     all_rating  all_rating_count          app_name  \
# 0          5.0                 2      ! Insta-Face
# 1          0.0                 0  ! Insta-Face Pro
# 10         2.0                 1           !R News
#
#                                 bundle_id content_rating    downloads  \
# 0                   bytesinarow.instaface   Low Maturity  500 - 1,000
# 1                bytesinarow.instafacepro       Everyone        1 - 5
# 10  com.realactionsoft.android.free.rnews       Everyone    100 - 500
#
#    file_size             genre  \
# 0       364k            Social
# 1       888k            Social
# 10      723k  News & Magazines
#
#                                              icon_url  \
# 0   https://lh6.ggpht.com/tLAk2kdsvWf22tEdsFHrN-Kv...
# 1   https://lh3.ggpht.com/cdJqCdM6ymrFHE69JxglBm9p...
# 10  https://lh6.ggpht.com/wDUilzAH1eR6WrTmzftYiM33...
#
#                                        id  price  price1
# 0                   bytesinarow.instaface   Free    0.00
# 1                bytesinarow.instafacepro  $0.99    0.99
# 10  com.realactionsoft.android.free.rnews   Free    0.00

# %%
dfdownloads=df[["app_name","downloads"]]

# %% [markdown]
# Changing the range of 'Downloads' to the mean of the range

# %%
import string
def modifydownloads(x):
    tempstring = str(x)
    if str(x)=="1 - 5":
        tempstring = str(x).replace("1 - 5","3")
    elif str(x)=="5 - 10":
        tempstring = str(x).replace("5 - 10","8")
    elif str(x)=="10 - 50":
        tempstring = str(x).replace("10 - 50","30")
    elif str(x)=="50 - 100":
        tempstring = str(x).replace("50 - 100","75")
    elif str(x)=="100 - 500":
        tempstring = str(x).replace("100 - 500","300")
    elif str(x)=="500 - 1,000":
        tempstring = str(x).replace("500 - 1,000","750")
    elif str(x)=="1,000 - 5,000":
        tempstring = str(x).replace("1,000 - 5,000","3000")
    elif str(x)=="5,000 - 10,000":
        tempstring = str(x).replace("5,000 - 10,000","7500")
    elif str(x)=="10,000 - 50,000":
        tempstring = str(x).replace("10,000 - 50,000","30000")
    elif str(x)=="50,000 - 100,000":
        tempstring = str(x).replace("50,000 - 100,000","75000")
    elif str(x)=="100,000 - 500,000":
        tempstring = str(x).replace("100,000 - 500,000","300000")
    elif str(x)=="500,000 - 1,000,000":
        tempstring = str(x).replace("500,000 - 1,000,000","750000")
    elif str(x)=="1,000,000 - 5,000,000":
        tempstring = str(x).replace("1,000,000 - 5,000,000","3000000")
    elif str(x)=="5,000,000 - 10,000,000":
        tempstring = str(x).replace("5,000,000 - 10,000,000","7500000")
    elif str(x)=="10,000,000 - 50,000,000":
        tempstring = str(x).replace("10,000,000 - 50,000,000","30000000")
    elif str(x)=="50,000,000 - 100,000,000":
        tempstring = str(x).replace("50,000,000 - 100,000,000","75000000")
    elif str(x)=="100,000,000 - 500,000,000":
        tempstring = str(x).replace("100,000,000 - 500,000,000","300000000")
    else:
        tempstring = str(x).replace("","0")
    return int(tempstring)

# %%
dfdownloads["downloads1"] = dfdownloads["downloads"].apply(lambda x: modifydownloads(str(x)))
# Out:
# C:\Users\chait\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
dfdownloads
# Out:
#                               app_name              downloads  downloads1
# 0                         ! Insta-Face            500 - 1,000         750
# 1                     ! Insta-Face Pro                  1 - 5           3
# 10                             !R News              100 - 500         300
# 100             "Memory" - Memory game    500,000 - 1,000,000      750000
# 1000                  000-341 IBM Free                 5 - 10           8
# 10000                       4 in a row              100 - 500         300
# 100000       Cats X HD Live Wallpapers              100 - 500         300
# 100001                  Cats and Bombs              100 - 500         300
# 100002    Cats and Dogs Live Wallpaper              100 - 500         300
# 100003         Cats and Dogs Ringtones              100 - 500         300
# 100004            Cats and Dogs Sounds        10,000 - 50,000       30000
# 100005  Cats and Furniture - Interiors                  1 - 5           3
# 100006                Cats and Rooster            500 - 1,000         750
# 100007     Cats and darts for children                10 - 50          30
# 100008         Cats and games for kids               50 - 100          75
# 100009        Cats calculator [useful]          1,000 - 5,000        3000
# 10001                       4 in a row  1,000,000 - 5,000,000     3000000
# 100010  Cats eat fish - Battery Widget                  1 - 5           3
# 100011              Cats enclyclopedia        10,000 - 50,000       30000
# 100012                   Cats for kids                 5 - 10           8
# 100013                  Cats in a Tree                  1 - 5           3
# 100014    Cats live wallpaper (Heart )         5,000 - 10,000        7500
# 100015  Cats my Love HD Live Wallpaper               50 - 100          75
# 100016         Cats notifiers for POPs        10,000 - 50,000       30000
# 100017         Cats of Prey Wallpapers            500 - 1,000         750
# 100018               Cats of the world        10,000 - 50,000       30000
# 100019     Cats of the world (Premium)              100 - 500         300
# 10002           4 in a row MULTIPLAYER       50,000 - 100,000       75000
# 100020      Cats playing with puffball              100 - 500         300
# 100021              Cats poems　preview              100 - 500         300
# ...                                ...                    ...         ...
# 99972                  Cats Photo Book                  1 - 5           3
# 99973               Cats Photo Effects          1,000 - 5,000        3000
# 99974                      Cats Puzzle        10,000 - 50,000       30000
# 99975                      Cats Puzzle          1,000 - 5,000        3000
# 99976                      Cats Puzzle       50,000 - 100,000       75000
# 99977                    Cats Puzzle 2          1,000 - 5,000        3000
# 99978                 Cats Puzzle 2 HD          1,000 - 5,000        3000
# 99979                   Cats Puzzle HD        10,000 - 50,000       30000
# 9998                       4 in a line              100 - 500         300
# 99980                      Cats Quotes                10 - 50          30
# 99981                   Cats Slideshow                  1 - 5           3
# 99982                      Cats Sounds    500,000 - 1,000,000      750000
# 99983                      Cats Sounds       50,000 - 100,000       75000
# 99984         Cats Spot the Difference        10,000 - 50,000       30000
# 99985         Cats Theme Coco Launcher         5,000 - 10,000        7500
# 99986                        Cats Town              100 - 500         300
# 99987   Cats Training - complete guide                  1 - 5           3
# 99988                      Cats Trivia          1,000 - 5,000        3000
# 99989                      Cats Trivia               50 - 100          75
# 9999                       4 in a mine              100 - 500         300
# 99990                   Cats Wallpaper                  1 - 5           3
# 99991              Cats Wallpaper Free              100 - 500         300
# 99992                  Cats Wallpapers                                  0
# 99993                  Cats Wallpapers       50,000 - 100,000       75000
# 99994                  Cats Wallpapers         5,000 - 10,000        7500
# 99995                  Cats Wallpapers              100 - 500         300
# 99996                Cats Wallpapers +              100 - 500         300
# 99997               Cats Wallpapers HD         5,000 - 10,000        7500
# 99998       Cats Winter Live Wallpaper                10 - 50          30
# 99999       Cats Winter Live Wallpaper                  1 - 5           3
#
# [187555 rows x 3 columns]

# %%
dfdownloads["downloads1"].unique()
# Out:
# array([      750,         3,       300,    750000,         8,     30000,
#               30,        75,      3000,   3000000,      7500,     75000,
#           300000,         0,   7500000,  30000000,  75000000, 300000000], dtype=int64)

# %%
dfdownloads.dtypes
# Out:
# app_name      object
# downloads     object
# downloads1     int64
# dtype: object

# %%
df1["downloads1"] = df1["downloads"].apply(lambda x: modifydownloads(str(x)))

# %%
df1.head(100)
# Out:
#         all_rating  all_rating_count                        app_name  \
# 0              5.0                 2                    ! Insta-Face
# 1              0.0                 0                ! Insta-Face Pro
# 10             2.0                 1                         !R News
# 100            4.3              1671          "Memory" - Memory game
# 1000           0.0                 0                000-341 IBM Free
# 10000          3.0                 2                      4 in a row
# 100000         1.5                 2       Cats X HD Live Wallpapers
# 100001         0.0                 0                  Cats and Bombs
# 100002         3.2                 9    Cats and Dogs Live Wallpaper
# 100003         5.0                 2         Cats and Dogs Ringtones
# 100004         4.2                58            Cats and Dogs Sounds
# 100005         0.0                 0  Cats and Furniture - Interiors
# 100006         3.5                 2                Cats and Rooster
# 100007         0.0                 0     Cats and darts for children
# 100008         0.0                 0         Cats and games for kids
# 100009         3.4                19        Cats calculator [useful]
# 10001          4.4             31069                      4 in a row
# 100010         0.0                 0  Cats eat fish - Battery Widget
# 100011         4.0               132              Cats enclyclopedia
# 100012         0.0                 0                   Cats for kids
# 100013         5.0                 2                  Cats in a Tree
# 100014         4.1                27    Cats live wallpaper (Heart )
# 100015         0.0                 0  Cats my Love HD Live Wallpaper
# 100016         4.6               104         Cats notifiers for POPs
# 100017         4.3                 6         Cats of Prey Wallpapers
# 100018         4.5               157               Cats of the world
# 100019         4.6                25     Cats of the world (Premium)
# 10002          3.5                81          4 in a row MULTIPLAYER
# 100020         3.7                 3      Cats playing with puffball
# 100021         5.0                 5              Cats poems　preview
# ...            ...               ...                             ...
# 100059         3.0                 2                     Catwalk Cat
# 10006          4.2              3092                4 teh birds lite
# 100060         3.5                 4                   Catwalk Queen
# 100061         4.2               704                         Catwang
# 100062         0.0                 0           Catwoman Snowfall LWP
# 100063         0.0                 0      Catwoman Theme Dark Knight
# 100064         5.0                 1  Catwoman vs Black Widow Wallpa
# 100065         5.0                 2                       Catwoman!
# 100066         5.0                 1                  Catxapp Navata
# 100067         4.7                 3                       Caty Food
# 100068         5.0                 6              Catálogo Beira Rio
# 100069         0.0                 0             Catálogo Cartorural
# 10007          0.0                 0        4 романа Алексея Иванова
# 100070         0.0                 0       Catálogo Cuisinart - 2012
# 100071         0.0                 0            Catálogo Médico SPDM
# 100072         5.0                 1                     Catálogo SH
# 100073         0.0                 0                 Catálogo Siamar
# 100074         5.0                25      Catálogo TPV y periféricos
# 100075         0.0                 0   Catálogo Turístico de Tabasco
# 100076         5.0                 4   Catálogo de Produtos - Sony -
# 100077         4.9              1336                 Católico Orante
# 100078         4.9                46        Católico Orante (Doação)
# 100079         4.5                20                 Católicos en T!
# 10008          3.3                 9               4-H News & Events
# 100080         5.0                 1                    Cau be 3 mat
# 100081         4.2                10                    Cau be YaiBa
# 100082         0.0                 0            Cau chuyen dong song
# 100083         0.0                 0              Cau vong tren bien
# 100084         0.0                 0               Caucasians Jame-z
# 100085         5.0                 2                    Caudrevision
#
#                                           bundle_id   content_rating  \
# 0                             bytesinarow.instaface     Low Maturity
# 1                          bytesinarow.instafacepro         Everyone
# 10            com.realactionsoft.android.free.rnews         Everyone
# 100                    com.berniiiiiiii.logomatchup         Everyone
# 1000                            org.exactqa.a000341    High Maturity
# 10000                             com.biblum.cuatro         Everyone
# 100000                              com.polins.cats     Low Maturity
# 100001                      com.serialscreener.cabs     Low Maturity
# 100002                       com.RainingCatsAndDogs         Everyone
# 100003                           com.kt.catsanddogs         Everyone
# 100004      com.juicyapplications.catsanddogssounds         Everyone
# 100005               jp.co.nec.app.android.am821054         Everyone
# 100006                      com.tidels.moralstory10     Low Maturity
# 100007               com.tengriprod.dartgameforkids     Low Maturity
# 100008                  com.tengri.catsgamesforkids     Low Maturity
# 100009                        jp.co.everred.CatCalc         Everyone
# 10001               com.magmamobile.game.fourinarow         Everyone
# 100010             com.blue.batterywidgetcateatfish         Everyone
# 100011                              com.darwin.cats         Everyone
# 100012                                cats.forkids1        Not rated
# 100013                              air.catsinatree         Everyone
# 100014                        kr.rain.WallPaperCatC     Low Maturity
# 100015          com.tojwoo.catmylovehdlivewallpaper  Medium Maturity
# 100016                          com.pops.packs.cats         Everyone
# 100017           com.dreamtree.catsofpreywallpapers         Everyone
# 100018                 com.mik61.catsoftheworldfree         Everyone
# 100019              com.mik61.catsoftheworldpremium         Everyone
# 10002                   com.skiller.games.furinarow         Everyone
# 100020                     jp.tjkapp.tegakinuko4lwp         Everyone
# 100021        jp.co.visionare.AndroidMAGIC_00000158         Everyone
# ...                                             ...              ...
# 100059                  com.MarjupiGames.CatwalkCat         Everyone
# 10006                                  viv.tehbirds         Everyone
# 100060                com.appfactory.android.bw.m26         Everyone
# 100061                                  com.fs.catw     Low Maturity
# 100062                      ovo.catwomansnowfalllwp         Everyone
# 100063  com.nd.android.pandatheme.p_dkcatwomandkrrw         Everyone
# 100064                     com.think.android.bulk67  Medium Maturity
# 100065    com.a197785792250721a5700d130a.a70084388a    High Maturity
# 100066                           cat.catxapp.navata     Low Maturity
# 100067                        com.vsg1.vsg.catyfood         Everyone
# 100068              com.Visiorama.BeiraRio.Catalogo         Everyone
# 100069             com.alborgis.catalogo_cartorural     Low Maturity
# 10007                              org.prospekt0352         Everyone
# 100070          pub.gfcgc.catalogo.AOTPVBUCFJAHJPHX     Low Maturity
# 100071                                     com.spdm         Everyone
# 100072                                com.coderockr         Everyone
# 100073              br.com.Williarts.CatalogoSiamar         Everyone
# 100074                       your.phonegap.posiflex     Low Maturity
# 100075                        com.sectur.catalogoes     Low Maturity
# 100076         pub.gfcgp.catalogo.AOTRICVYLTMAJHPOR     Low Maturity
# 100077                  com.raribeir.catolicoorante         Everyone
# 100078          com.raribeir.catolicoorantedonation    High Maturity
# 100079                            com.catlicos.en.t         Everyone
# 10008                   com.Inconceivable.FourHNews         Everyone
# 100080                      com.dft.comic.caube3mat         Everyone
# 100081                          com.dft.comic.yaiba         Everyone
# 100082         com.pbgs.mobileads.cauchuyendongsong     Low Maturity
# 100083                   com.pbgs.mobileads.cauvong     Low Maturity
# 100084           com.reverbnation.artistapp.i778691     Low Maturity
# 100085                     com.doubley.caudrevision         Everyone
#
#                     downloads           file_size              genre  \
# 0                 500 - 1,000                364k             Social
# 1                       1 - 5                888k             Social
# 10                  100 - 500                723k   News & Magazines
# 100       500,000 - 1,000,000                2.2M     Brain & Puzzle
# 1000                   5 - 10                372k          Education
# 10000               100 - 500                1.9M     Brain & Puzzle
# 100000              100 - 500                4.5M      Entertainment
# 100001              100 - 500                 13M    Arcade & Action
# 100002              100 - 500                 13M    Personalization
# 100003              100 - 500                6.1M    Personalization
# 100004        10,000 - 50,000                3.3M      Entertainment
# 100005                  1 - 5                6.8M          Lifestyle
# 100006            500 - 1,000                 22M          Education
# 100007                10 - 50                 11M             Casual
# 100008               50 - 100                 22M             Casual
# 100009          1,000 - 5,000                2.2M              Tools
# 10001   1,000,000 - 5,000,000                2.1M     Brain & Puzzle
# 100010                  1 - 5                346k              Tools
# 100011        10,000 - 50,000                185k  Books & Reference
# 100012                 5 - 10                3.7M             Casual
# 100013                  1 - 5                1.9M          Education
# 100014         5,000 - 10,000                3.3M      Entertainment
# 100015               50 - 100                2.7M      Entertainment
# 100016        10,000 - 50,000                2.1M    Personalization
# 100017            500 - 1,000                 12M    Personalization
# 100018        10,000 - 50,000                 17M  Books & Reference
# 100019              100 - 500                 17M  Books & Reference
# 10002        50,000 - 100,000                1.7M             Casual
# 100020              100 - 500                826k    Personalization
# 100021              100 - 500                 27M      Media & Video
# ...                       ...                 ...                ...
# 100059              100 - 500                7.3M      Entertainment
# 10006       100,000 - 500,000                2.2M    Arcade & Action
# 100060          1,000 - 5,000                900k   News & Magazines
# 100061       50,000 - 100,000                 11M      Entertainment
# 100062               50 - 100                272k    Personalization
# 100063                 5 - 10                1.8M    Personalization
# 100064              100 - 500                2.1M        Photography
# 100065            500 - 1,000                957k          Lifestyle
# 100066                10 - 50                1.2M     Travel & Local
# 100067                10 - 50                1.2M     Brain & Puzzle
# 100068              100 - 500                7.3M           Business
# 100069                10 - 50                1.7M     Travel & Local
# 10007                 10 - 50                 11M  Books & Reference
# 100070               50 - 100                1.9M           Business
# 100071                10 - 50                1.4M            Medical
# 100072              100 - 500                 39M           Business
# 100073                10 - 50                6.2M           Shopping
# 100074            500 - 1,000  Varies with device           Business
# 100075                                        31M     Travel & Local
# 100076          1,000 - 5,000                4.7M           Shopping
# 100077        10,000 - 50,000                2.3M          Lifestyle
# 100078              100 - 500                2.1M          Lifestyle
# 100079          1,000 - 5,000                960k   News & Magazines
# 10008             500 - 1,000                936k      Communication
# 100080          1,000 - 5,000                3.3M             Comics
# 100081          1,000 - 5,000                2.5M             Comics
# 100082              100 - 500                860k  Books & Reference
# 100083              100 - 500                1.4M  Books & Reference
# 100084                                       4.1M      Music & Audio
# 100085               50 - 100                2.1M   News & Magazines
#
#                                                  icon_url  \
# 0       https://lh6.ggpht.com/tLAk2kdsvWf22tEdsFHrN-Kv...
# 1       https://lh3.ggpht.com/cdJqCdM6ymrFHE69JxglBm9p...
# 10      https://lh6.ggpht.com/wDUilzAH1eR6WrTmzftYiM33...
# 100     https://lh6.ggpht.com/imRDG-WyO4o6C73YKUYYrUrH...
# 1000    https://lh6.ggpht.com/LBOKsylnAFds3WaJGS1KLSBx...
# 10000   https://lh6.ggpht.com/XonyAWKMp_Fc25uA3J6bOPXn...
# 100000  https://lh6.ggpht.com/8CtaPuNJzGgn30bAg8JQOJ1M...
# 100001  https://lh4.ggpht.com/f8CPX9q9iYWxj3DVj5Ql6uvn...
# 100002  https://lh3.ggpht.com/7FEi8tzVxeivcX_yMMzqVCom...
# 100003  https://lh3.ggpht.com/m8m0pSYwSAcfXmEHlQ8Dz7v6...
# 100004  https://lh3.ggpht.com/Inhxv4Ei2aQpVfBqYwuIeYEF...
# 100005  https://lh3.ggpht.com/iqldogLzNwe2c3c0cnVayjCK...
# 100006  https://lh3.ggpht.com/Vs0zOFJ7WEr6ocJ24bzbShh_...
# 100007  https://lh6.ggpht.com/vw_dSzID7UFdmfVKYv9aCwlv...
# 100008  https://lh5.ggpht.com/dT43Eqi-374HtZiXJ_l76sJf...
# 100009  https://lh6.ggpht.com/WscwDronAVQlzqwOIWiS5cz-...
# 10001   https://lh3.ggpht.com/zIJTCg6peri0bZ9YksVNXO6t...
# 100010  https://lh3.ggpht.com/MsKZSTdXgL4xwPwdGizbkzQX...
# 100011  https://lh5.ggpht.com/2aSrTKj9xHCeGdM24uEFT2lz...
# 100012  https://lh6.ggpht.com/1o5kDke2lo41dkl9RvUfYb1R...
# 100013  https://lh4.ggpht.com/34vBIlVYvVjb3TgvArfdmJL8...
# 100014  https://lh6.ggpht.com/2SPOqnA_XCm7sK2AkroI1CRJ...
# 100015  https://lh5.ggpht.com/YVZbcJq-ueR4nY8g6luRHG-3...
# 100016  https://lh4.ggpht.com/BdWYH9XmZtHg7z9vOpGTqBb1...
# 100017  https://lh5.ggpht.com/far1iaEs-FXkt2pbDq1rQIXu...
# 100018  https://lh5.ggpht.com/6ozhWwu8XOl90DxqdelcQrbI...
# 100019  https://lh3.ggpht.com/LAS-dBxd62fbD2MOwCL4xs2F...
# 10002   https://lh5.ggpht.com/KzTQlakE2h28yaO7pBkQZnGR...
# 100020  https://lh5.ggpht.com/YgkKz-fitlg-EXZDzhYkTW5z...
# 100021  https://lh5.ggpht.com/yoKdyN3TUDXoWf6cG1sh4_Ou...
# ...                                                   ...
# 100059  https://lh5.ggpht.com/dcpukBH9Lc8lTlQz4ehLb3Tx...
# 10006   https://lh5.ggpht.com/rDxXq9Aou3TBhVaVvU1oEfMe...
# 100060  https://lh6.ggpht.com/O_rNjuVLQ395e7Xia-p-VwMd...
# 100061  https://lh6.ggpht.com/6L9-9FIfnFnBtY6lAxUj3R7W...
# 100062  https://lh3.ggpht.com/T16yY_X-uvrp9H7sHAYFUWMS...
# 100063  https://lh3.ggpht.com/_RN2MxUzV7165tl8ImbNJZYv...
# 100064  https://lh5.ggpht.com/MtBSE6wmTFw93ojPzyiHeP_0...
# 100065  https://lh4.ggpht.com/dm3Hi9FVOvaCVUJGGkNMUp14...
# 100066  https://lh6.ggpht.com/TfAjjiZryah9Zzb-0VzdKFkQ...
# 100067  https://lh3.ggpht.com/zVLNVU7PTl635UzgTk6ZiScH...
# 100068  https://lh6.ggpht.com/GYNnOJ68nHyRnzZGtXRKq87G...
# 100069  https://lh4.ggpht.com/qZNwzR2AmF9coq754Ti5-3OB...
# 10007   https://lh6.ggpht.com/aeFEcukQeZfUAqAR_dsKXd2l...
# 100070  https://lh4.ggpht.com/f6Zmy9P-kYCXSO_FzOc43FOh...
# 100071  https://lh6.ggpht.com/dooTsZg4dUjJC2LZeAsmlkbq...
# 100072  https://lh6.ggpht.com/9ONOFiZgsyV8Drk_aXlwxohP...
# 100073  https://lh3.ggpht.com/2mTd_lHNfjjZI1Vwl5yo2rgg...
# 100074  https://lh4.ggpht.com/cG7xAvn-3Edk9ovvYFhMKwUQ...
# 100075  https://lh5.ggpht.com/-K7dR_ER0GD0xI4kPSey_OuZ...
# 100076  https://lh4.ggpht.com/3a7c0z_tRigGxMF1pZM_5bMc...
# 100077  https://lh5.ggpht.com/uXOJtUmqqnjCe84gcNrkWsRO...
# 100078  https://lh5.ggpht.com/Pd2RZ8lYkzI-yCMFl3xX87JV...
# 100079  https://lh5.ggpht.com/Rlf4i6r1vGAE2O_bcFqmHw1z...
# 10008   https://lh5.ggpht.com/Y5CIdK9cT7g74-pHV2YZPN-r...
# 100080  https://lh3.ggpht.com/VuOvsUTzS6xQb7vfD3X0tgAs...
# 100081  https://lh6.ggpht.com/w2l2I7nff5gdbuUDHTlhXntO...
# 100082  https://lh5.ggpht.com/-jQ4HIAd4S9sAxMoLddKNcvt...
# 100083  https://lh4.ggpht.com/0442RB3IrNtNO-YNJU5xN11c...
# 100084  https://lh6.ggpht.com/EGMV2auX3TsCBPC7bEQXgJn5...
# 100085  https://lh3.ggpht.com/0lbBK2DlRMd5-hIhGHTEziQq...
#
#                                                  id  price  price1  downloads1
# 0                             bytesinarow.instaface   Free    0.00         750
# 1                          bytesinarow.instafacepro  $0.99    0.99           3
# 10            com.realactionsoft.android.free.rnews   Free    0.00         300
# 100                    com.berniiiiiiii.logomatchup   Free    0.00      750000
# 1000                            org.exactqa.a000341   Free    0.00           8
# 10000                             com.biblum.cuatro   Free    0.00         300
# 100000                              com.polins.cats   Free    0.00         300
# 100001                      com.serialscreener.cabs   Free    0.00         300
# 100002                       com.RainingCatsAndDogs  $1.49    1.49         300
# 100003                           com.kt.catsanddogs   Free    0.00         300
# 100004      com.juicyapplications.catsanddogssounds   Free    0.00       30000
# 100005               jp.co.nec.app.android.am821054  $1.41    1.41           3
# 100006                      com.tidels.moralstory10   Free    0.00         750
# 100007               com.tengriprod.dartgameforkids   Free    0.00          30
# 100008                  com.tengri.catsgamesforkids   Free    0.00          75
# 100009                        jp.co.everred.CatCalc   Free    0.00        3000
# 10001               com.magmamobile.game.fourinarow   Free    0.00     3000000
# 100010             com.blue.batterywidgetcateatfish  $0.99    0.99           3
# 100011                              com.darwin.cats   Free    0.00       30000
# 100012                                cats.forkids1  $2.25    2.25           8
# 100013                              air.catsinatree  $0.99    0.99           3
# 100014                        kr.rain.WallPaperCatC   Free    0.00        7500
# 100015          com.tojwoo.catmylovehdlivewallpaper   Free    0.00          75
# 100016                          com.pops.packs.cats   Free    0.00       30000
# 100017           com.dreamtree.catsofpreywallpapers   Free    0.00         750
# 100018                 com.mik61.catsoftheworldfree   Free    0.00       30000
# 100019              com.mik61.catsoftheworldpremium  $3.00    3.00         300
# 10002                   com.skiller.games.furinarow   Free    0.00       75000
# 100020                     jp.tjkapp.tegakinuko4lwp  $1.13    1.13         300
# 100021        jp.co.visionare.AndroidMAGIC_00000158   Free    0.00         300
# ...                                             ...    ...     ...         ...
# 100059                  com.MarjupiGames.CatwalkCat   Free    0.00         300
# 10006                                  viv.tehbirds   Free    0.00      300000
# 100060                com.appfactory.android.bw.m26   Free    0.00        3000
# 100061                                  com.fs.catw   Free    0.00       75000
# 100062                      ovo.catwomansnowfalllwp   Free    0.00          75
# 100063  com.nd.android.pandatheme.p_dkcatwomandkrrw  $1.59    1.59           8
# 100064                     com.think.android.bulk67   Free    0.00         300
# 100065    com.a197785792250721a5700d130a.a70084388a   Free    0.00         750
# 100066                           cat.catxapp.navata   Free    0.00          30
# 100067                        com.vsg1.vsg.catyfood   Free    0.00          30
# 100068              com.Visiorama.BeiraRio.Catalogo   Free    0.00         300
# 100069             com.alborgis.catalogo_cartorural   Free    0.00          30
# 10007                              org.prospekt0352  $2.99    2.99          30
# 100070          pub.gfcgc.catalogo.AOTPVBUCFJAHJPHX   Free    0.00          75
# 100071                                     com.spdm   Free    0.00          30
# 100072                                com.coderockr   Free    0.00         300
# 100073              br.com.Williarts.CatalogoSiamar   Free    0.00          30
# 100074                       your.phonegap.posiflex   Free    0.00         750
# 100075                        com.sectur.catalogoes   Free    0.00           0
# 100076         pub.gfcgp.catalogo.AOTRICVYLTMAJHPOR   Free    0.00        3000
# 100077                  com.raribeir.catolicoorante   Free    0.00       30000
# 100078          com.raribeir.catolicoorantedonation  $1.50    1.50         300
# 100079                            com.catlicos.en.t   Free    0.00        3000
# 10008                   com.Inconceivable.FourHNews   Free    0.00         750
# 100080                      com.dft.comic.caube3mat   Free    0.00        3000
# 100081                          com.dft.comic.yaiba   Free    0.00        3000
# 100082         com.pbgs.mobileads.cauchuyendongsong   Free    0.00         300
# 100083                   com.pbgs.mobileads.cauvong   Free    0.00         300
# 100084           com.reverbnation.artistapp.i778691   Free    0.00           0
# 100085                     com.doubley.caudrevision   Free    0.00          75
#
# [100 rows x 13 columns]

# %%
dfsize= df[["id", "file_size"]]

# %% [markdown]
# Convert all the values in the column 'file_size' to Mb.

# %%
def changeFileSize(x):
    tempstring = str(x)
    tempstring = tempstring.replace(",","")
    if str(x).endswith("k"):
        tempstring = tempstring.rstrip("k") 
        tempfloat = float(tempstring)
        return float(tempfloat/1000)
    if str(x).endswith("M"):
        tempstring = tempstring.rstrip("M")
        return float(tempstring)
    else:
        return int(0.0)

# %%
dfsize["file_size1"] = dfsize["file_size"].apply(lambda x: changeFileSize(str(x)))
# Out:
# C:\Users\chait\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
dfsize
# Out:
#                                                id file_size  file_size1
# 0                           bytesinarow.instaface      364k       0.364
# 1                        bytesinarow.instafacepro      888k       0.888
# 10          com.realactionsoft.android.free.rnews      723k       0.723
# 100                  com.berniiiiiiii.logomatchup      2.2M       2.200
# 1000                          org.exactqa.a000341      372k       0.372
# 10000                           com.biblum.cuatro      1.9M       1.900
# 100000                            com.polins.cats      4.5M       4.500
# 100001                    com.serialscreener.cabs       13M      13.000
# 100002                     com.RainingCatsAndDogs       13M      13.000
# 100003                         com.kt.catsanddogs      6.1M       6.100
# 100004    com.juicyapplications.catsanddogssounds      3.3M       3.300
# 100005             jp.co.nec.app.android.am821054      6.8M       6.800
# 100006                    com.tidels.moralstory10       22M      22.000
# 100007             com.tengriprod.dartgameforkids       11M      11.000
# 100008                com.tengri.catsgamesforkids       22M      22.000
# 100009                      jp.co.everred.CatCalc      2.2M       2.200
# 10001             com.magmamobile.game.fourinarow      2.1M       2.100
# 100010           com.blue.batterywidgetcateatfish      346k       0.346
# 100011                            com.darwin.cats      185k       0.185
# 100012                              cats.forkids1      3.7M       3.700
# 100013                            air.catsinatree      1.9M       1.900
# 100014                      kr.rain.WallPaperCatC      3.3M       3.300
# 100015        com.tojwoo.catmylovehdlivewallpaper      2.7M       2.700
# 100016                        com.pops.packs.cats      2.1M       2.100
# 100017         com.dreamtree.catsofpreywallpapers       12M      12.000
# 100018               com.mik61.catsoftheworldfree       17M      17.000
# 100019            com.mik61.catsoftheworldpremium       17M      17.000
# 10002                 com.skiller.games.furinarow      1.7M       1.700
# 100020                   jp.tjkapp.tegakinuko4lwp      826k       0.826
# 100021      jp.co.visionare.AndroidMAGIC_00000158       27M      27.000
# ...                                           ...       ...         ...
# 99972                      org.digiglyph.eyw.cats       27M      27.000
# 99973                            com.myeffect.cat      843k       0.843
# 99974                              com.catspuzzle      6.0M       6.000
# 99975                          com.droidcorp.cats      5.1M       5.100
# 99976                      com.akolacz.catspuzzle      5.8M       5.800
# 99977                     com.akolacz.cats2puzzle      3.2M       3.200
# 99978                   com.akolacz.cats2puzzlehd      4.7M       4.700
# 99979                    com.akolacz.catspuzzlehd      8.1M       8.100
# 9998                                   pg.FourWin      116k       0.116
# 99980                   com.book.mbpl.catsquotes1      268k       0.268
# 99981    com.ExitFortyFive.lwp.lwpcatsslideshowjz      2.5M       2.500
# 99982                              com.catssounds      690k       0.690
# 99983                                com.cutecats      2.5M       2.500
# 99984                            com.m2h.spotcats       12M      12.000
# 99985            coco.monochromecats.theme0002_02      760k       0.760
# 99986                           com.catstown.main      188k       0.188
# 99987                com.appbuilder.u46225p166841      2.3M       2.300
# 99988                     org.arnon10.Cats_Trivia      1.8M       1.800
# 99989     com.quipack.a.b4fa8ffdb49860c000103eab8      2.2M       2.200
# 9999                    com.malerbati.fourInAMine      297k       0.297
# 99990       com.bubbuware.android.wall.irene.cats      2.7M       2.700
# 99991   com.bubbuware.android.wall.irene.catsfree      1.3M       1.300
# 99992   com.howtomakemillionswithapps.app490XAWYU      178k       0.178
# 99993                       com.facewolf.catslite      2.4M       2.400
# 99994                         com.cats.wallpapers      495k       0.495
# 99995          net.mercurysoftware.catswallpapers      8.7M       8.700
# 99996                           com.facewolf.cats      3.2M       3.200
# 99997                                hddroid.cats       42k       0.042
# 99998                  com.custom.lwp.catswinterr      642k       0.642
# 99999                  com.custom.lwp.catwintterr      1.1M       1.100
#
# [187555 rows x 3 columns]

# %%
df1["file_size1"] = df1["file_size"].apply(lambda x: changeFileSize(str(x)))

# %%
df1.head(10)
# Out:
#         all_rating  all_rating_count                      app_name  \
# 0              5.0                 2                  ! Insta-Face
# 1              0.0                 0              ! Insta-Face Pro
# 10             2.0                 1                       !R News
# 100            4.3              1671        "Memory" - Memory game
# 1000           0.0                 0              000-341 IBM Free
# 10000          3.0                 2                    4 in a row
# 100000         1.5                 2     Cats X HD Live Wallpapers
# 100001         0.0                 0                Cats and Bombs
# 100002         3.2                 9  Cats and Dogs Live Wallpaper
# 100003         5.0                 2       Cats and Dogs Ringtones
#
#                                     bundle_id content_rating  \
# 0                       bytesinarow.instaface   Low Maturity
# 1                    bytesinarow.instafacepro       Everyone
# 10      com.realactionsoft.android.free.rnews       Everyone
# 100              com.berniiiiiiii.logomatchup       Everyone
# 1000                      org.exactqa.a000341  High Maturity
# 10000                       com.biblum.cuatro       Everyone
# 100000                        com.polins.cats   Low Maturity
# 100001                com.serialscreener.cabs   Low Maturity
# 100002                 com.RainingCatsAndDogs       Everyone
# 100003                     com.kt.catsanddogs       Everyone
#
#                   downloads file_size             genre  \
# 0               500 - 1,000      364k            Social
# 1                     1 - 5      888k            Social
# 10                100 - 500      723k  News & Magazines
# 100     500,000 - 1,000,000      2.2M    Brain & Puzzle
# 1000                 5 - 10      372k         Education
# 10000             100 - 500      1.9M    Brain & Puzzle
# 100000            100 - 500      4.5M     Entertainment
# 100001            100 - 500       13M   Arcade & Action
# 100002            100 - 500       13M   Personalization
# 100003            100 - 500      6.1M   Personalization
#
#                                                  icon_url  \
# 0       https://lh6.ggpht.com/tLAk2kdsvWf22tEdsFHrN-Kv...
# 1       https://lh3.ggpht.com/cdJqCdM6ymrFHE69JxglBm9p...
# 10      https://lh6.ggpht.com/wDUilzAH1eR6WrTmzftYiM33...
# 100     https://lh6.ggpht.com/imRDG-WyO4o6C73YKUYYrUrH...
# 1000    https://lh6.ggpht.com/LBOKsylnAFds3WaJGS1KLSBx...
# 10000   https://lh6.ggpht.com/XonyAWKMp_Fc25uA3J6bOPXn...
# 100000  https://lh6.ggpht.com/8CtaPuNJzGgn30bAg8JQOJ1M...
# 100001  https://lh4.ggpht.com/f8CPX9q9iYWxj3DVj5Ql6uvn...
# 100002  https://lh3.ggpht.com/7FEi8tzVxeivcX_yMMzqVCom...
# 100003  https://lh3.ggpht.com/m8m0pSYwSAcfXmEHlQ8Dz7v6...
#
#                                            id  price  price1  downloads1  \
# 0                       bytesinarow.instaface   Free    0.00         750
# 1                    bytesinarow.instafacepro  $0.99    0.99           3
# 10      com.realactionsoft.android.free.rnews   Free    0.00         300
# 100              com.berniiiiiiii.logomatchup   Free    0.00      750000
# 1000                      org.exactqa.a000341   Free    0.00           8
# 10000                       com.biblum.cuatro   Free    0.00         300
# 100000                        com.polins.cats   Free    0.00         300
# 100001                com.serialscreener.cabs   Free    0.00         300
# 100002                 com.RainingCatsAndDogs  $1.49    1.49         300
# 100003                     com.kt.catsanddogs   Free    0.00         300
#
#         file_size1
# 0            0.364
# 1            0.888
# 10           0.723
# 100          2.200
# 1000         0.372
# 10000        1.900
# 100000       4.500
# 100001      13.000
# 100002      13.000
# 100003       6.100

# %%
df2=df1[["app_name","bundle_id","all_rating","all_rating_count","genre","icon_url","downloads","downloads1","file_size","file_size1","price","price1"]]

# %%
df2.head(5)
# Out:
#                     app_name                              bundle_id  \
# 0               ! Insta-Face                  bytesinarow.instaface
# 1           ! Insta-Face Pro               bytesinarow.instafacepro
# 10                   !R News  com.realactionsoft.android.free.rnews
# 100   "Memory" - Memory game           com.berniiiiiiii.logomatchup
# 1000        000-341 IBM Free                    org.exactqa.a000341
#
#       all_rating  all_rating_count             genre  \
# 0            5.0                 2            Social
# 1            0.0                 0            Social
# 10           2.0                 1  News & Magazines
# 100          4.3              1671    Brain & Puzzle
# 1000         0.0                 0         Education
#
#                                                icon_url            downloads  \
# 0     https://lh6.ggpht.com/tLAk2kdsvWf22tEdsFHrN-Kv...          500 - 1,000
# 1     https://lh3.ggpht.com/cdJqCdM6ymrFHE69JxglBm9p...                1 - 5
# 10    https://lh6.ggpht.com/wDUilzAH1eR6WrTmzftYiM33...            100 - 500
# 100   https://lh6.ggpht.com/imRDG-WyO4o6C73YKUYYrUrH...  500,000 - 1,000,000
# 1000  https://lh6.ggpht.com/LBOKsylnAFds3WaJGS1KLSBx...               5 - 10
#
#       downloads1 file_size  file_size1  price  price1
# 0            750      364k       0.364   Free    0.00
# 1              3      888k       0.888  $0.99    0.99
# 10           300      723k       0.723   Free    0.00
# 100       750000      2.2M       2.200   Free    0.00
# 1000           8      372k       0.372   Free    0.00

# %%
df2.drop('price', axis=1, inplace=True)
# Out:
# C:\Users\chait\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df2.drop('downloads', axis=1,inplace=True)
# Out:
# C:\Users\chait\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df2.drop('file_size', axis=1,inplace=True)
# Out:
# C:\Users\chait\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df2.head(3)
# Out:
#             app_name                              bundle_id  all_rating  \
# 0       ! Insta-Face                  bytesinarow.instaface         5.0
# 1   ! Insta-Face Pro               bytesinarow.instafacepro         0.0
# 10           !R News  com.realactionsoft.android.free.rnews         2.0
#
#     all_rating_count             genre  \
# 0                  2            Social
# 1                  0            Social
# 10                 1  News & Magazines
#
#                                              icon_url  downloads1  file_size1  \
# 0   https://lh6.ggpht.com/tLAk2kdsvWf22tEdsFHrN-Kv...         750       0.364
# 1   https://lh3.ggpht.com/cdJqCdM6ymrFHE69JxglBm9p...           3       0.888
# 10  https://lh6.ggpht.com/wDUilzAH1eR6WrTmzftYiM33...         300       0.723
#
#     price1
# 0     0.00
# 1     0.99
# 10    0.00

# %%
df2.rename(columns={"downloads1": "downloads", "file_size1": "file_size", "price1":"price"},inplace=True)

# %%
df2.head(3)
# Out:
#             app_name                              bundle_id  all_rating  \
# 0       ! Insta-Face                  bytesinarow.instaface         5.0
# 1   ! Insta-Face Pro               bytesinarow.instafacepro         0.0
# 10           !R News  com.realactionsoft.android.free.rnews         2.0
#
#     all_rating_count             genre  \
# 0                  2            Social
# 1                  0            Social
# 10                 1  News & Magazines
#
#                                              icon_url  downloads  file_size  \
# 0   https://lh6.ggpht.com/tLAk2kdsvWf22tEdsFHrN-Kv...        750      0.364
# 1   https://lh3.ggpht.com/cdJqCdM6ymrFHE69JxglBm9p...          3      0.888
# 10  https://lh6.ggpht.com/wDUilzAH1eR6WrTmzftYiM33...        300      0.723
#
#     price
# 0    0.00
# 1    0.99
# 10   0.00

# %%
df2.to_json(path_or_buf="tempjson1.json")

# %% [markdown]
# ## Verification

# %%
dftemp=pd.read_json(path_or_buf="tempjson1.json")

# %%
dftemp.head(50)
# Out:
#         all_rating  all_rating_count                        app_name  \
# 0              5.0                 2                    ! Insta-Face
# 1              0.0                 0                ! Insta-Face Pro
# 10             2.0                 1                         !R News
# 100            4.3              1671          "Memory" - Memory game
# 1000           0.0                 0                000-341 IBM Free
# 10000          3.0                 2                      4 in a row
# 100000         1.5                 2       Cats X HD Live Wallpapers
# 100001         0.0                 0                  Cats and Bombs
# 100002         3.2                 9    Cats and Dogs Live Wallpaper
# 100003         5.0                 2         Cats and Dogs Ringtones
# 100004         4.2                58            Cats and Dogs Sounds
# 100005         0.0                 0  Cats and Furniture - Interiors
# 100006         3.5                 2                Cats and Rooster
# 100007         0.0                 0     Cats and darts for children
# 100008         0.0                 0         Cats and games for kids
# 100009         3.4                19        Cats calculator [useful]
# 10001          4.4             31069                      4 in a row
# 100010         0.0                 0  Cats eat fish - Battery Widget
# 100011         4.0               132              Cats enclyclopedia
# 100012         0.0                 0                   Cats for kids
# 100013         5.0                 2                  Cats in a Tree
# 100014         4.1                27    Cats live wallpaper (Heart )
# 100015         0.0                 0  Cats my Love HD Live Wallpaper
# 100016         4.6               104         Cats notifiers for POPs
# 100017         4.3                 6         Cats of Prey Wallpapers
# 100018         4.5               157               Cats of the world
# 100019         4.6                25     Cats of the world (Premium)
# 10002          3.5                81          4 in a row MULTIPLAYER
# 100020         3.7                 3      Cats playing with puffball
# 100021         5.0                 5              Cats poems　preview
# 100022         4.4                14                     Cats puzzle
# 100023         2.0                 2            Cats puzzle (jigsaw)
# 100024         3.3               104                     Cats sounds
# 100025         0.0                 0                Cats video links
# 100026         2.5                 2            Cats wallpapers +900
# 100027         5.0                 1       Cats! Lasers! Explosions!
# 100028         0.0                 0                       Cats&Dogs
# 100029         4.7                50                      Cats, Inc.
# 10003          3.0                43            4 lata wakacji Tuska
# 100030         4.3               289             Cats. Jigsaw Puzzle
# 100031         4.7                 7              Cats: Breed Guide!
# 100032         5.0                 6                CatsBlock Camera
# 100033         5.0                 2          Catskill New York - NY
# 100034         4.0                41                    Catskurukuru
# 100035         5.0                 1                      Catstagram
# 100036         5.0                 1                           Catsu
# 100037         0.0                 0                     Catsup RTWE
# 100038         3.6                24                          Cattes
# 100039         0.0                 0  Cattle Brands - Western Camp-f
# 10004          0.0                 0                       4 saisons
#
#                                                 bundle_id  downloads  \
# 0                                   bytesinarow.instaface        750
# 1                                bytesinarow.instafacepro          3
# 10                  com.realactionsoft.android.free.rnews        300
# 100                          com.berniiiiiiii.logomatchup     750000
# 1000                                  org.exactqa.a000341          8
# 10000                                   com.biblum.cuatro        300
# 100000                                    com.polins.cats        300
# 100001                            com.serialscreener.cabs        300
# 100002                             com.RainingCatsAndDogs        300
# 100003                                 com.kt.catsanddogs        300
# 100004            com.juicyapplications.catsanddogssounds      30000
# 100005                     jp.co.nec.app.android.am821054          3
# 100006                            com.tidels.moralstory10        750
# 100007                     com.tengriprod.dartgameforkids         30
# 100008                        com.tengri.catsgamesforkids         75
# 100009                              jp.co.everred.CatCalc       3000
# 10001                     com.magmamobile.game.fourinarow    3000000
# 100010                   com.blue.batterywidgetcateatfish          3
# 100011                                    com.darwin.cats      30000
# 100012                                      cats.forkids1          8
# 100013                                    air.catsinatree          3
# 100014                              kr.rain.WallPaperCatC       7500
# 100015                com.tojwoo.catmylovehdlivewallpaper         75
# 100016                                com.pops.packs.cats      30000
# 100017                 com.dreamtree.catsofpreywallpapers        750
# 100018                       com.mik61.catsoftheworldfree      30000
# 100019                    com.mik61.catsoftheworldpremium        300
# 10002                         com.skiller.games.furinarow      75000
# 100020                           jp.tjkapp.tegakinuko4lwp        300
# 100021              jp.co.visionare.AndroidMAGIC_00000158        300
# 100022                                com.fla.puzzle.cats       3000
# 100023                         air.pl.mtjk.puzzlepussycat        750
# 100024                            com.photobeat.catsounds      30000
# 100025                           com.corocorocat.nekolink         75
# 100026                           com.Cutecats.Cutecats900       3000
# 100027                     com.yuska.catslasersexplosions          8
# 100028                               com.appsbuilder28886          3
# 100029                               com.appmania.catsinc       3000
# 10003                                     com.gra.chmurki       3000
# 100030                           coder.hamster.jpall.cats     300000
# 100031                                  com.klexicon.cats       3000
# 100032                         air.tw.com.enjoyplay.app03        300
# 100033                             com.chamberme.catskill        300
# 100034                           com.corocorocat.kurukuru      30000
# 100035                             biz.shoprev.catstagram        300
# 100036                                 com.moongate.catsu         30
# 100037                     com.droidxitin.ruvnbdtimjaiktw          3
# 100038                                   com.yospos.catte       7500
# 100039  com.digimediaapps.Cattle_Brands___Western_Camp...         30
# 10004                   com.myapphone.android.les4saisons          8
#
#         file_size              genre  \
# 0           0.364             Social
# 1           0.888             Social
# 10          0.723   News & Magazines
# 100         2.200     Brain & Puzzle
# 1000        0.372          Education
# 10000       1.900     Brain & Puzzle
# 100000      4.500      Entertainment
# 100001     13.000    Arcade & Action
# 100002     13.000    Personalization
# 100003      6.100    Personalization
# 100004      3.300      Entertainment
# 100005      6.800          Lifestyle
# 100006     22.000          Education
# 100007     11.000             Casual
# 100008     22.000             Casual
# 100009      2.200              Tools
# 10001       2.100     Brain & Puzzle
# 100010      0.346              Tools
# 100011      0.185  Books & Reference
# 100012      3.700             Casual
# 100013      1.900          Education
# 100014      3.300      Entertainment
# 100015      2.700      Entertainment
# 100016      2.100    Personalization
# 100017     12.000    Personalization
# 100018     17.000  Books & Reference
# 100019     17.000  Books & Reference
# 10002       1.700             Casual
# 100020      0.826    Personalization
# 100021     27.000      Media & Video
# 100022      2.700     Brain & Puzzle
# 100023      1.200     Brain & Puzzle
# 100024      4.500      Music & Audio
# 100025      0.072      Entertainment
# 100026      0.740    Personalization
# 100027      0.556    Personalization
# 100028      0.452            Medical
# 100029     14.000    Arcade & Action
# 10003       9.000    Arcade & Action
# 100030      5.600     Brain & Puzzle
# 100031      5.500          Lifestyle
# 100032     14.000        Photography
# 100033      7.400     Travel & Local
# 100034      0.093        Photography
# 100035      5.100        Photography
# 100036      1.800             Casual
# 100037      0.959      Entertainment
# 100038      0.038      Entertainment
# 100039      0.919  Books & Reference
# 10004       1.700          Lifestyle
#
#                                                  icon_url  price
# 0       https://lh6.ggpht.com/tLAk2kdsvWf22tEdsFHrN-Kv...   0.00
# 1       https://lh3.ggpht.com/cdJqCdM6ymrFHE69JxglBm9p...   0.99
# 10      https://lh6.ggpht.com/wDUilzAH1eR6WrTmzftYiM33...   0.00
# 100     https://lh6.ggpht.com/imRDG-WyO4o6C73YKUYYrUrH...   0.00
# 1000    https://lh6.ggpht.com/LBOKsylnAFds3WaJGS1KLSBx...   0.00
# 10000   https://lh6.ggpht.com/XonyAWKMp_Fc25uA3J6bOPXn...   0.00
# 100000  https://lh6.ggpht.com/8CtaPuNJzGgn30bAg8JQOJ1M...   0.00
# 100001  https://lh4.ggpht.com/f8CPX9q9iYWxj3DVj5Ql6uvn...   0.00
# 100002  https://lh3.ggpht.com/7FEi8tzVxeivcX_yMMzqVCom...   1.49
# 100003  https://lh3.ggpht.com/m8m0pSYwSAcfXmEHlQ8Dz7v6...   0.00
# 100004  https://lh3.ggpht.com/Inhxv4Ei2aQpVfBqYwuIeYEF...   0.00
# 100005  https://lh3.ggpht.com/iqldogLzNwe2c3c0cnVayjCK...   1.41
# 100006  https://lh3.ggpht.com/Vs0zOFJ7WEr6ocJ24bzbShh_...   0.00
# 100007  https://lh6.ggpht.com/vw_dSzID7UFdmfVKYv9aCwlv...   0.00
# 100008  https://lh5.ggpht.com/dT43Eqi-374HtZiXJ_l76sJf...   0.00
# 100009  https://lh6.ggpht.com/WscwDronAVQlzqwOIWiS5cz-...   0.00
# 10001   https://lh3.ggpht.com/zIJTCg6peri0bZ9YksVNXO6t...   0.00
# 100010  https://lh3.ggpht.com/MsKZSTdXgL4xwPwdGizbkzQX...   0.99
# 100011  https://lh5.ggpht.com/2aSrTKj9xHCeGdM24uEFT2lz...   0.00
# 100012  https://lh6.ggpht.com/1o5kDke2lo41dkl9RvUfYb1R...   2.25
# 100013  https://lh4.ggpht.com/34vBIlVYvVjb3TgvArfdmJL8...   0.99
# 100014  https://lh6.ggpht.com/2SPOqnA_XCm7sK2AkroI1CRJ...   0.00
# 100015  https://lh5.ggpht.com/YVZbcJq-ueR4nY8g6luRHG-3...   0.00
# 100016  https://lh4.ggpht.com/BdWYH9XmZtHg7z9vOpGTqBb1...   0.00
# 100017  https://lh5.ggpht.com/far1iaEs-FXkt2pbDq1rQIXu...   0.00
# 100018  https://lh5.ggpht.com/6ozhWwu8XOl90DxqdelcQrbI...   0.00
# 100019  https://lh3.ggpht.com/LAS-dBxd62fbD2MOwCL4xs2F...   3.00
# 10002   https://lh5.ggpht.com/KzTQlakE2h28yaO7pBkQZnGR...   0.00
# 100020  https://lh5.ggpht.com/YgkKz-fitlg-EXZDzhYkTW5z...   1.13
# 100021  https://lh5.ggpht.com/yoKdyN3TUDXoWf6cG1sh4_Ou...   0.00
# 100022  https://lh3.ggpht.com/8hut6CSgIzZ0gIIK2XFcvH74...   0.00
# 100023  https://lh4.ggpht.com/gEl3dN3IzM82DGFbUftrjsUy...   0.00
# 100024  https://lh5.ggpht.com/ckWzCdHOq_0an50l3UGEbPJt...   0.00
# 100025  https://lh3.ggpht.com/-Zlkvvtyz0stleJUaEj0HHX3...   0.00
# 100026  https://lh6.ggpht.com/456W9zhnMrXZ4mwgJXOSt37P...   0.00
# 100027  https://lh6.ggpht.com/B9LRF2HmoI1ErrSVwGfh_KqQ...   1.00
# 100028  https://lh4.ggpht.com/RLF9ioqXhQ5LEp2nQy_7ZXZV...   0.99
# 100029  https://lh3.ggpht.com/mU1v18uqS2-GCDPzZNmtC4vM...   0.00
# 10003   https://lh6.ggpht.com/e_Cwv4kaESRanCq3OA2euZgY...   0.00
# 100030  https://lh6.ggpht.com/fEa2nJbDEOleoheK_RvStS_P...   0.00
# 100031  https://lh4.ggpht.com/HIjenyMT2lxRAdBQHyjOLLye...   0.00
# 100032  https://lh4.ggpht.com/mtp7oNVAsjQufnCEsP2iIzEq...   0.00
# 100033  https://lh4.ggpht.com/5q9GpOBRk2wHUtdJ1-5GjJdM...   0.00
# 100034  https://lh5.ggpht.com/SR24o7-h43E7OphBK8E_Aw6R...   0.00
# 100035  https://lh6.ggpht.com/vgIlcoQQWhK5Z5wIfiwjMYPY...   0.00
# 100036  https://lh5.ggpht.com/M86f2RV-dW64zCHfkCGUgPgd...   0.00
# 100037  https://lh3.ggpht.com/OLco6kdpQ0wIIQir8rle8t_P...   0.00
# 100038  https://lh3.ggpht.com/__FrwFgaEBNEJvbguEip2tJK...   0.00
# 100039  https://lh4.ggpht.com/_WblKCAS5Jb9ntCRoKeBoj21...   0.99
# 10004   https://lh6.ggpht.com/r6lrHIEvkFgh4tT2ucuStANc...   0.00
