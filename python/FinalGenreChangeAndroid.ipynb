# %%
import pandas as pd

# %%
df=pd.read_json(path_or_buf="clean_android_all.json")

# %%
df.columns
# Out:
# Index([u'age', u'all_rating', u'all_rating_count', u'app_name', u'bundle_id',
#        u'date', u'downloads', u'epoch_date', u'file_size', u'genre',
#        u'icon_url', u'price'],
#       dtype='object')

# %%
df["genre"].unique()
# Out:
# array([u'Social', u'Entertainment', u'Shopping', u'Brain & Puzzle',
#        u'Media & Video', u'Personalization', u'Education',
#        u'Health & Fitness', u'Photography', u'Lifestyle',
#        u'Arcade & Action', u'Books & Reference', u'Communication',
#        u'Productivity', u'Tools', u'Business', u'Comics',
#        u'News & Magazines', u'Travel & Local', u'Medical',
#        u'Music & Audio', u'Sports', u'Finance', u'Racing', u'Casual',
#        u'Transportation', u'Libraries & Demo', u'Cards & Casino',
#        u'Weather', u'Sports Games'], dtype=object)

# %%
dfitunes=pd.read_json(path_or_buf="cleaned_itunes.json", typ="frame",lines=True)

# %%
dfitunes.columns
# Out:
# Index([u'all_rating', u'all_rating_count', u'app_name', u'bundle_id',
#        u'content_rating', u'file_size_bytes', u'file_size_in_mb', u'genre',
#        u'i_age', u'i_date', u'icon_url', u'id', u'price'],
#       dtype='object')

# %%
dfitunes["genre"].unique()
# Out:
# array([u'Utilities', u'Finance', u'Games', u'Education', u'Books',
#        u'Lifestyle', u'Music', u'Social Networking', u'News',
#        u'Entertainment', u'Photo & Video', u'Navigation',
#        u'Health & Fitness', u'Sports', u'Business', u'Productivity',
#        u'Reference', u'Travel', u'Food & Drink', u'Medical', u'Weather',
#        u'Catalogs'], dtype=object)

# %%
df["mod_genre"]=df["genre"]

# %%
df["mod_genre"].replace('Social','Social Networking',inplace=True)

# %%
df.head(10)
# Out:
#         age  all_rating  all_rating_count                      app_name  \
# 0       345         5.0                 2                  ! Insta-Face
# 10      340         4.2                58          Cats and Dogs Sounds
# 1000    531         3.9               535                         Ceneo
# 10000   503         4.0                66              Christmas Trivia
# 100000  315         4.3                 6    Abstract Live Wallpaper HD
# 100001  215         3.9                 7   Abstract Live Wallpaper LWP
# 100002  454         4.2                 5                    #DAILYROCK
# 100004  668         4.2               114  Abstract Live Wallpaper Pack
# 100005  290         4.6                19          Abstract Love Locker
# 100006  540         2.0                 1  Abstract Mega Live Wallpaper
#
#                                         bundle_id       date  downloads  \
# 0                           bytesinarow.instaface 2012-07-21        750
# 10        com.juicyapplications.catsanddogssounds 2012-07-26      30000
# 1000                                     pl.ceneo 2012-01-17     300000
# 10000                     com.alaskajim.christmas 2012-02-14      75000
# 100000                      com.redgirl.abstracts 2012-08-20        300
# 100001              com.abstractlivewallpaper.lwp 2012-11-28       3000
# 100002                             com.wDailyRock 2012-04-03        300
# 100004                        cz.kinst.jakub.alwp 2011-09-02      30000
# 100005  com.lockerscreenexpert.abstractlovelocker 2012-09-14       3000
# 100006    com.abstractmegalivewallpaper.stardroid 2012-01-08        300
#
#         epoch_date  file_size            genre  \
# 0       1342828800      0.364           Social
# 10      1343260800      3.300    Entertainment
# 1000    1326758400      0.693         Shopping
# 10000   1329177600      2.600   Brain & Puzzle
# 100000  1345420800      2.600    Media & Video
# 100001  1354060800      1.500  Personalization
# 100002  1333411200      0.101        Education
# 100004  1314921600      0.355  Personalization
# 100005  1347580800      2.200  Personalization
# 100006  1325980800      3.700           Social
#
#                                                  icon_url  price  \
# 0       https://lh6.ggpht.com/tLAk2kdsvWf22tEdsFHrN-Kv...    0.0
# 10      https://lh3.ggpht.com/Inhxv4Ei2aQpVfBqYwuIeYEF...    0.0
# 1000    https://lh6.ggpht.com/uWe2mtTPzQkPGJF7zvmR-iRU...    0.0
# 10000   https://lh5.ggpht.com/IannWJ66OYxzQrh0TjDBbcqz...    0.0
# 100000  https://lh6.ggpht.com/P-A5UG84v8SVElolXiZafitv...    0.0
# 100001  https://lh5.ggpht.com/N_hORKLNn502toOANoyZzc-H...    0.0
# 100002  https://lh3.ggpht.com/R1_elehi1wZQf4x00TAUQxHZ...    0.0
# 100004  https://lh4.ggpht.com/OoRAHuE0Xx7nI71ZZOpoEtt7...    0.0
# 100005  https://lh4.ggpht.com/JVLqfPZHmeHHUYtZIjzHbIPB...    0.0
# 100006  https://lh5.ggpht.com/haptDojw_VPAtHnQ5Q7seRu8...    0.0
#
#                 mod_genre
# 0       Social Networking
# 10          Entertainment
# 1000             Shopping
# 10000      Brain & Puzzle
# 100000      Media & Video
# 100001    Personalization
# 100002          Education
# 100004    Personalization
# 100005    Personalization
# 100006  Social Networking

# %%
df["mod_genre"].replace('Brain & Puzzle','Games',inplace=True)

# %%
df["mod_genre"].replace('Media & Video','Photo & Video',inplace=True)

# %%
df["mod_genre"].replace('Personalization','Entertainment',inplace=True)

# %%
df["mod_genre"].replace('Photography','Photo & Video',inplace=True)

# %%
df["mod_genre"].replace('Arcade & Action','Games',inplace=True)

# %%
df["mod_genre"].replace('Communication','Social Networking',inplace=True)

# %%
df["mod_genre"].replace('Tools','Utilities',inplace=True)

# %%
df["mod_genre"].replace('Comics','Entertainment',inplace=True)

# %%
df["mod_genre"].replace('News & Magazines','News',inplace=True)

# %%
df["mod_genre"].replace('Travel & Local','Travel',inplace=True)

# %%
df["mod_genre"].replace('Music & Audio','Music',inplace=True)

# %%
df["mod_genre"].replace('Racing','Games',inplace=True)

# %%
df["mod_genre"].replace('Casual','Games',inplace=True)

# %%
df["mod_genre"].replace('Transportation','Navigation',inplace=True)

# %%
df["mod_genre"].replace('Libraries & Demo','Entertainment',inplace=True)

# %%
df["mod_genre"].replace('Cards & Casino','Games',inplace=True)

# %%
df["mod_genre"].replace('Sports Games','Games',inplace=True)

# %%
len(df["genre"].unique())
# Out:
# 30

# %%
df["genre"].unique()
# Out:
# array([u'Social', u'Entertainment', u'Shopping', u'Brain & Puzzle',
#        u'Media & Video', u'Personalization', u'Education',
#        u'Health & Fitness', u'Photography', u'Lifestyle',
#        u'Arcade & Action', u'Books & Reference', u'Communication',
#        u'Productivity', u'Tools', u'Business', u'Comics',
#        u'News & Magazines', u'Travel & Local', u'Medical',
#        u'Music & Audio', u'Sports', u'Finance', u'Racing', u'Casual',
#        u'Transportation', u'Libraries & Demo', u'Cards & Casino',
#        u'Weather', u'Sports Games'], dtype=object)

# %%
len(df["mod_genre"].unique())
# Out:
# 20

# %%
df.head(10)
# Out:
#         age  all_rating  all_rating_count                      app_name  \
# 0       345         5.0                 2                  ! Insta-Face
# 10      340         4.2                58          Cats and Dogs Sounds
# 1000    531         3.9               535                         Ceneo
# 10000   503         4.0                66              Christmas Trivia
# 100000  315         4.3                 6    Abstract Live Wallpaper HD
# 100001  215         3.9                 7   Abstract Live Wallpaper LWP
# 100002  454         4.2                 5                    #DAILYROCK
# 100004  668         4.2               114  Abstract Live Wallpaper Pack
# 100005  290         4.6                19          Abstract Love Locker
# 100006  540         2.0                 1  Abstract Mega Live Wallpaper
#
#                                         bundle_id       date  downloads  \
# 0                           bytesinarow.instaface 2012-07-21        750
# 10        com.juicyapplications.catsanddogssounds 2012-07-26      30000
# 1000                                     pl.ceneo 2012-01-17     300000
# 10000                     com.alaskajim.christmas 2012-02-14      75000
# 100000                      com.redgirl.abstracts 2012-08-20        300
# 100001              com.abstractlivewallpaper.lwp 2012-11-28       3000
# 100002                             com.wDailyRock 2012-04-03        300
# 100004                        cz.kinst.jakub.alwp 2011-09-02      30000
# 100005  com.lockerscreenexpert.abstractlovelocker 2012-09-14       3000
# 100006    com.abstractmegalivewallpaper.stardroid 2012-01-08        300
#
#         epoch_date  file_size            genre  \
# 0       1342828800      0.364           Social
# 10      1343260800      3.300    Entertainment
# 1000    1326758400      0.693         Shopping
# 10000   1329177600      2.600   Brain & Puzzle
# 100000  1345420800      2.600    Media & Video
# 100001  1354060800      1.500  Personalization
# 100002  1333411200      0.101        Education
# 100004  1314921600      0.355  Personalization
# 100005  1347580800      2.200  Personalization
# 100006  1325980800      3.700           Social
#
#                                                  icon_url  price  \
# 0       https://lh6.ggpht.com/tLAk2kdsvWf22tEdsFHrN-Kv...    0.0
# 10      https://lh3.ggpht.com/Inhxv4Ei2aQpVfBqYwuIeYEF...    0.0
# 1000    https://lh6.ggpht.com/uWe2mtTPzQkPGJF7zvmR-iRU...    0.0
# 10000   https://lh5.ggpht.com/IannWJ66OYxzQrh0TjDBbcqz...    0.0
# 100000  https://lh6.ggpht.com/P-A5UG84v8SVElolXiZafitv...    0.0
# 100001  https://lh5.ggpht.com/N_hORKLNn502toOANoyZzc-H...    0.0
# 100002  https://lh3.ggpht.com/R1_elehi1wZQf4x00TAUQxHZ...    0.0
# 100004  https://lh4.ggpht.com/OoRAHuE0Xx7nI71ZZOpoEtt7...    0.0
# 100005  https://lh4.ggpht.com/JVLqfPZHmeHHUYtZIjzHbIPB...    0.0
# 100006  https://lh5.ggpht.com/haptDojw_VPAtHnQ5Q7seRu8...    0.0
#
#                 mod_genre
# 0       Social Networking
# 10          Entertainment
# 1000             Shopping
# 10000               Games
# 100000      Photo & Video
# 100001      Entertainment
# 100002          Education
# 100004      Entertainment
# 100005      Entertainment
# 100006  Social Networking

# %%
dfitunes.columns
# Out:
# Index([u'all_rating', u'all_rating_count', u'app_name', u'bundle_id',
#        u'content_rating', u'file_size_bytes', u'file_size_in_mb', u'genre',
#        u'i_age', u'i_date', u'icon_url', u'id', u'price'],
#       dtype='object')

# %%
dfitunes["genre"].replace('Food & Drink','Lifestyle',inplace=True)

# %%
dfitunes["genre"].replace('Books','Books & Reference',inplace=True)

# %%
dfitunes["genre"].replace('Reference','Books & Reference',inplace=True)

# %%
dfitunes["genre"].unique()
# Out:
# array([u'Utilities', u'Finance', u'Games', u'Education',
#        'Books & Reference', u'Lifestyle', u'Music', u'Social Networking',
#        u'News', u'Entertainment', u'Photo & Video', u'Navigation',
#        u'Health & Fitness', u'Sports', u'Business', u'Productivity',
#        u'Travel', u'Medical', u'Weather', u'Catalogs'], dtype=object)

# %%
df.to_json(path_or_buf="clean_android_allcolumns.json",orient="records",lines=True)

# %% [markdown]
# dftemp= pd.read_json(path_or_buf="clean_android_allcolumns.json", typ="frame")

# %%
dftemp= pd.read_json(path_or_buf="clean_android_allcolumns.json", typ="frame", lines=True)

# %%
dftemp.head(10)
# Out:
#    age  all_rating  all_rating_count                      app_name  \
# 0  345         5.0                 2                  ! Insta-Face
# 1  340         4.2                58          Cats and Dogs Sounds
# 2  531         3.9               535                         Ceneo
# 3  503         4.0                66              Christmas Trivia
# 4  315         4.3                 6    Abstract Live Wallpaper HD
# 5  215         3.9                 7   Abstract Live Wallpaper LWP
# 6  454         4.2                 5                    #DAILYROCK
# 7  668         4.2               114  Abstract Live Wallpaper Pack
# 8  290         4.6                19          Abstract Love Locker
# 9  540         2.0                 1  Abstract Mega Live Wallpaper
#
#                                    bundle_id       date  downloads  \
# 0                      bytesinarow.instaface 2012-07-21        750
# 1    com.juicyapplications.catsanddogssounds 2012-07-26      30000
# 2                                   pl.ceneo 2012-01-17     300000
# 3                    com.alaskajim.christmas 2012-02-14      75000
# 4                      com.redgirl.abstracts 2012-08-20        300
# 5              com.abstractlivewallpaper.lwp 2012-11-28       3000
# 6                             com.wDailyRock 2012-04-03        300
# 7                        cz.kinst.jakub.alwp 2011-09-02      30000
# 8  com.lockerscreenexpert.abstractlovelocker 2012-09-14       3000
# 9    com.abstractmegalivewallpaper.stardroid 2012-01-08        300
#
#    epoch_date  file_size            genre  \
# 0  1342828800      0.364           Social
# 1  1343260800      3.300    Entertainment
# 2  1326758400      0.693         Shopping
# 3  1329177600      2.600   Brain & Puzzle
# 4  1345420800      2.600    Media & Video
# 5  1354060800      1.500  Personalization
# 6  1333411200      0.101        Education
# 7  1314921600      0.355  Personalization
# 8  1347580800      2.200  Personalization
# 9  1325980800      3.700           Social
#
#                                             icon_url          mod_genre  price
# 0  https://lh6.ggpht.com/tLAk2kdsvWf22tEdsFHrN-Kv...  Social Networking    0.0
# 1  https://lh3.ggpht.com/Inhxv4Ei2aQpVfBqYwuIeYEF...      Entertainment    0.0
# 2  https://lh6.ggpht.com/uWe2mtTPzQkPGJF7zvmR-iRU...           Shopping    0.0
# 3  https://lh5.ggpht.com/IannWJ66OYxzQrh0TjDBbcqz...              Games    0.0
# 4  https://lh6.ggpht.com/P-A5UG84v8SVElolXiZafitv...      Photo & Video    0.0
# 5  https://lh5.ggpht.com/N_hORKLNn502toOANoyZzc-H...      Entertainment    0.0
# 6  https://lh3.ggpht.com/R1_elehi1wZQf4x00TAUQxHZ...          Education    0.0
# 7  https://lh4.ggpht.com/OoRAHuE0Xx7nI71ZZOpoEtt7...      Entertainment    0.0
# 8  https://lh4.ggpht.com/JVLqfPZHmeHHUYtZIjzHbIPB...      Entertainment    0.0
# 9  https://lh5.ggpht.com/haptDojw_VPAtHnQ5Q7seRu8...  Social Networking    0.0

# %%
dftemp["WOM"] = 0
dftemp.head(10)
# Out:
#    age  all_rating  all_rating_count                      app_name  \
# 0  345         5.0                 2                  ! Insta-Face
# 1  340         4.2                58          Cats and Dogs Sounds
# 2  531         3.9               535                         Ceneo
# 3  503         4.0                66              Christmas Trivia
# 4  315         4.3                 6    Abstract Live Wallpaper HD
# 5  215         3.9                 7   Abstract Live Wallpaper LWP
# 6  454         4.2                 5                    #DAILYROCK
# 7  668         4.2               114  Abstract Live Wallpaper Pack
# 8  290         4.6                19          Abstract Love Locker
# 9  540         2.0                 1  Abstract Mega Live Wallpaper
#
#                                    bundle_id       date  downloads  \
# 0                      bytesinarow.instaface 2012-07-21        750
# 1    com.juicyapplications.catsanddogssounds 2012-07-26      30000
# 2                                   pl.ceneo 2012-01-17     300000
# 3                    com.alaskajim.christmas 2012-02-14      75000
# 4                      com.redgirl.abstracts 2012-08-20        300
# 5              com.abstractlivewallpaper.lwp 2012-11-28       3000
# 6                             com.wDailyRock 2012-04-03        300
# 7                        cz.kinst.jakub.alwp 2011-09-02      30000
# 8  com.lockerscreenexpert.abstractlovelocker 2012-09-14       3000
# 9    com.abstractmegalivewallpaper.stardroid 2012-01-08        300
#
#    epoch_date  file_size            genre  \
# 0  1342828800      0.364           Social
# 1  1343260800      3.300    Entertainment
# 2  1326758400      0.693         Shopping
# 3  1329177600      2.600   Brain & Puzzle
# 4  1345420800      2.600    Media & Video
# 5  1354060800      1.500  Personalization
# 6  1333411200      0.101        Education
# 7  1314921600      0.355  Personalization
# 8  1347580800      2.200  Personalization
# 9  1325980800      3.700           Social
#
#                                             icon_url          mod_genre  \
# 0  https://lh6.ggpht.com/tLAk2kdsvWf22tEdsFHrN-Kv...  Social Networking
# 1  https://lh3.ggpht.com/Inhxv4Ei2aQpVfBqYwuIeYEF...      Entertainment
# 2  https://lh6.ggpht.com/uWe2mtTPzQkPGJF7zvmR-iRU...           Shopping
# 3  https://lh5.ggpht.com/IannWJ66OYxzQrh0TjDBbcqz...              Games
# 4  https://lh6.ggpht.com/P-A5UG84v8SVElolXiZafitv...      Photo & Video
# 5  https://lh5.ggpht.com/N_hORKLNn502toOANoyZzc-H...      Entertainment
# 6  https://lh3.ggpht.com/R1_elehi1wZQf4x00TAUQxHZ...          Education
# 7  https://lh4.ggpht.com/OoRAHuE0Xx7nI71ZZOpoEtt7...      Entertainment
# 8  https://lh4.ggpht.com/JVLqfPZHmeHHUYtZIjzHbIPB...      Entertainment
# 9  https://lh5.ggpht.com/haptDojw_VPAtHnQ5Q7seRu8...  Social Networking
#
#    price  WOM
# 0    0.0    0
# 1    0.0    0
# 2    0.0    0
# 3    0.0    0
# 4    0.0    0
# 5    0.0    0
# 6    0.0    0
# 7    0.0    0
# 8    0.0    0
# 9    0.0    0

# %%
df_utilities = dftemp[dftemp.mod_genre == 'Utilities']

# %%
df_utilities.head(10)
# Out:
#       age  all_rating  all_rating_count                       app_name  \
# 51    279         3.7                 3  1000s of Free HowTo Tutorials
# 128   654         4.3                56                       AbyssFTP
# 129   654         4.6                24                   AbyssFTP Pro
# 130   579         4.7                73                  Abyssea Clock
# 132   262         3.9                18                Ac Auto Hotspot
# 193  1161         4.3                 6                         AccMon
# 209   889         4.3                 3                    Accelerando
# 215   812         4.2                 5                   Acceleration
# 216  1289         2.9                21            Acceleration Drawer
# 217   684         3.3                15              Acceleration Free
#
#                                              bundle_id       date  downloads  \
# 51   com.ww1000sofFreeHowToTutorialArticlesandInfor... 2012-09-25        300
# 128                             com.droidsoft.abyssftp 2011-09-16      30000
# 129                         com.droidsoft.abyssftp.pro 2011-09-16        300
# 130                               jp.bave.abysseaclock 2011-11-30       7500
# 132                    com.greenflamingo.acautohotspot 2012-10-12       7500
# 193                               jp.shibax.app.AccMon 2010-04-27       3000
# 209                        com.app.bpit.ringtoneWidget 2011-01-24        300
# 215                          com.peacedout.lightsensor 2011-04-11       3000
# 216                         net.wumpuscave.acceldrawer 2009-12-20       3000
# 217           com.speedymarks.android.accelerationFree 2011-08-17       7500
#
#      epoch_date  file_size  genre  \
# 51   1348531200      0.212  Tools
# 128  1316131200      0.529  Tools
# 129  1316131200      0.547  Tools
# 130  1322611200      0.117  Tools
# 132  1350000000      0.026  Tools
# 193  1272326400      0.055  Tools
# 209  1295827200      0.226  Tools
# 215  1302480000      0.207  Tools
# 216  1261267200      0.008  Tools
# 217  1313539200      0.019  Tools
#
#                                               icon_url  mod_genre  price
# 51   https://lh4.ggpht.com/ZrFi5Hd9aSErk3FEVwXvGPte...  Utilities   0.00
# 128  https://lh4.ggpht.com/srttfaVwDGqFFdNowBWLFcAs...  Utilities   0.00
# 129  https://lh4.ggpht.com/7mlGrdvDZNBk8UPKoFEh6K6g...  Utilities   1.09
# 130  https://lh6.ggpht.com/_Q9PeKUFs-VfbUnNieE2_rOp...  Utilities   0.00
# 132  https://lh4.ggpht.com/8ulzyiVnDyzUeybUPsPGSOhX...  Utilities   0.00
# 193  https://lh3.ggpht.com/mnH1N47ooRmiRgZqI008F8vf...  Utilities   0.00
# 209  https://lh3.ggpht.com/WWCuA-FRYElkUbtLQOJKH-xi...  Utilities   0.00
# 215  https://lh6.ggpht.com/eQST4ZtU8w65WdKko9U-NZ5E...  Utilities   0.00
# 216  https://lh3.ggpht.com/RZvfwIuLplRp852kH6XQ6QIW...  Utilities   0.00
# 217  https://lh4.ggpht.com/8XGCxtPVX7UwMhDgSCLXJm58...  Utilities   0.00

# %%
df_utilities["WOM"] = df_utilities.downloads.mean()/df_utilities.all_rating_count.mean()
# Out:
# C:\Users\chait\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df_utilities.head(10)
# Out:
#       age  all_rating  all_rating_count                       app_name  \
# 51    279         3.7                 3  1000s of Free HowTo Tutorials
# 128   654         4.3                56                       AbyssFTP
# 129   654         4.6                24                   AbyssFTP Pro
# 130   579         4.7                73                  Abyssea Clock
# 132   262         3.9                18                Ac Auto Hotspot
# 193  1161         4.3                 6                         AccMon
# 209   889         4.3                 3                    Accelerando
# 215   812         4.2                 5                   Acceleration
# 216  1289         2.9                21            Acceleration Drawer
# 217   684         3.3                15              Acceleration Free
#
#                                              bundle_id       date  downloads  \
# 51   com.ww1000sofFreeHowToTutorialArticlesandInfor... 2012-09-25        300
# 128                             com.droidsoft.abyssftp 2011-09-16      30000
# 129                         com.droidsoft.abyssftp.pro 2011-09-16        300
# 130                               jp.bave.abysseaclock 2011-11-30       7500
# 132                    com.greenflamingo.acautohotspot 2012-10-12       7500
# 193                               jp.shibax.app.AccMon 2010-04-27       3000
# 209                        com.app.bpit.ringtoneWidget 2011-01-24        300
# 215                          com.peacedout.lightsensor 2011-04-11       3000
# 216                         net.wumpuscave.acceldrawer 2009-12-20       3000
# 217           com.speedymarks.android.accelerationFree 2011-08-17       7500
#
#      epoch_date  file_size  genre  \
# 51   1348531200      0.212  Tools
# 128  1316131200      0.529  Tools
# 129  1316131200      0.547  Tools
# 130  1322611200      0.117  Tools
# 132  1350000000      0.026  Tools
# 193  1272326400      0.055  Tools
# 209  1295827200      0.226  Tools
# 215  1302480000      0.207  Tools
# 216  1261267200      0.008  Tools
# 217  1313539200      0.019  Tools
#
#                                               icon_url  mod_genre  price  \
# 51   https://lh4.ggpht.com/ZrFi5Hd9aSErk3FEVwXvGPte...  Utilities   0.00
# 128  https://lh4.ggpht.com/srttfaVwDGqFFdNowBWLFcAs...  Utilities   0.00
# 129  https://lh4.ggpht.com/7mlGrdvDZNBk8UPKoFEh6K6g...  Utilities   1.09
# 130  https://lh6.ggpht.com/_Q9PeKUFs-VfbUnNieE2_rOp...  Utilities   0.00
# 132  https://lh4.ggpht.com/8ulzyiVnDyzUeybUPsPGSOhX...  Utilities   0.00
# 193  https://lh3.ggpht.com/mnH1N47ooRmiRgZqI008F8vf...  Utilities   0.00
# 209  https://lh3.ggpht.com/WWCuA-FRYElkUbtLQOJKH-xi...  Utilities   0.00
# 215  https://lh6.ggpht.com/eQST4ZtU8w65WdKko9U-NZ5E...  Utilities   0.00
# 216  https://lh3.ggpht.com/RZvfwIuLplRp852kH6XQ6QIW...  Utilities   0.00
# 217  https://lh4.ggpht.com/8XGCxtPVX7UwMhDgSCLXJm58...  Utilities   0.00
#
#             WOM
# 51   229.620125
# 128  229.620125
# 129  229.620125
# 130  229.620125
# 132  229.620125
# 193  229.620125
# 209  229.620125
# 215  229.620125
# 216  229.620125
# 217  229.620125

# %%
dfratios
# Out:
# array([u'Social', u'Entertainment', u'Shopping', u'Brain & Puzzle',
#        u'Media & Video', u'Personalization', u'Education',
#        u'Health & Fitness', u'Photography', u'Lifestyle',
#        u'Arcade & Action', u'Books & Reference', u'Communication',
#        u'Productivity', u'Tools', u'Business', u'Comics',
#        u'News & Magazines', u'Travel & Local', u'Medical',
#        u'Music & Audio', u'Sports', u'Finance', u'Racing', u'Casual',
#        u'Transportation', u'Libraries & Demo', u'Cards & Casino',
#        u'Weather', u'Sports Games'], dtype=object)

# %%
dfratios=pd.DataFrame(dftemp["mod_genre"])

# %%
dfratios.drop_duplicates(inplace=True)

# %%
dfratios
# Out:
#              mod_genre
# 0    Social Networking
# 1        Entertainment
# 2             Shopping
# 3                Games
# 4        Photo & Video
# 6            Education
# 12    Health & Fitness
# 16           Lifestyle
# 31   Books & Reference
# 47        Productivity
# 51           Utilities
# 66            Business
# 80                News
# 90              Travel
# 98             Medical
# 125              Music
# 147             Sports
# 164            Finance
# 220         Navigation
# 488            Weather

# %%
dfratios["WOM"]=0

# %%
dfratios
# Out:
#              mod_genre  WOM
# 0    Social Networking    0
# 1        Entertainment    0
# 2             Shopping    0
# 3                Games    0
# 4        Photo & Video    0
# 6            Education    0
# 12    Health & Fitness    0
# 16           Lifestyle    0
# 31   Books & Reference    0
# 47        Productivity    0
# 51           Utilities    0
# 66            Business    0
# 80                News    0
# 90              Travel    0
# 98             Medical    0
# 125              Music    0
# 147             Sports    0
# 164            Finance    0
# 220         Navigation    0
# 488            Weather    0

# %%
dfratios.iloc[10,1]=229.62

# %%
dfratios
# Out:
#              mod_genre     WOM
# 0    Social Networking    0.00
# 1        Entertainment    0.00
# 2             Shopping    0.00
# 3                Games    0.00
# 4        Photo & Video    0.00
# 6            Education    0.00
# 12    Health & Fitness    0.00
# 16           Lifestyle    0.00
# 31   Books & Reference    0.00
# 47        Productivity    0.00
# 51           Utilities  229.62
# 66            Business    0.00
# 80                News    0.00
# 90              Travel    0.00
# 98             Medical    0.00
# 125              Music    0.00
# 147             Sports    0.00
# 164            Finance    0.00
# 220         Navigation    0.00
# 488            Weather    0.00

# %%
df_finance = dftemp[dftemp.mod_genre == 'Finance']
df_games = dftemp[dftemp.mod_genre == 'Games']
df_education = dftemp[dftemp.mod_genre == 'Education']
df_books = dftemp[dftemp.mod_genre == 'Books & Reference']
df_lifestyle = dftemp[dftemp.mod_genre == 'Lifestyle']

# %%
df_finance.downloads.mean()/df_finance.all_rating_count.mean()
# Out:
# 197.19563432989173

# %%
dfratios.iloc[17,1]=197.2

# %%
dfratios
# Out:
#              mod_genre     WOM
# 0    Social Networking    0.00
# 1        Entertainment    0.00
# 2             Shopping    0.00
# 3                Games  132.16
# 4        Photo & Video    0.00
# 6            Education  324.74
# 12    Health & Fitness    0.00
# 16           Lifestyle  287.84
# 31   Books & Reference  217.47
# 47        Productivity    0.00
# 51           Utilities  229.62
# 66            Business    0.00
# 80                News    0.00
# 90              Travel    0.00
# 98             Medical    0.00
# 125              Music    0.00
# 147             Sports    0.00
# 164            Finance  197.20
# 220         Navigation    0.00
# 488            Weather    0.00

# %%
df_games.downloads.mean()/df_games.all_rating_count.mean()
# Out:
# 132.15924349863448

# %%
dfratios.iloc[3,1]=132.16

# %%
df_education.downloads.mean()/df_education.all_rating_count.mean()
# Out:
# 324.7368163582193

# %%
dfratios.iloc[5,1]=324.74

# %%
df_books.downloads.mean()/df_books.all_rating_count.mean()
# Out:
# 217.46689558411299

# %%
dfratios.iloc[8,1]=217.47

# %%
df_lifestyle.downloads.mean()/df_lifestyle.all_rating_count.mean()
# Out:
# 287.83991589063032

# %%
dfratios.iloc[7,1]=287.84

# %%
df_music = dftemp[dftemp.mod_genre == 'Music']
df_socialnetworking = dftemp[dftemp.mod_genre == 'Social Networking']
df_news  = dftemp[dftemp.mod_genre == 'News']
df_entertainment = dftemp[dftemp.mod_genre == 'Entertainment']
df_photo = dftemp[dftemp.mod_genre == 'Photo & Video']
df_navigation = dftemp[dftemp.mod_genre == 'Navigation']
df_health = dftemp[dftemp.mod_genre == 'Health & Fitness']
df_sports = dftemp[dftemp.mod_genre == 'Sports']
df_business = dftemp[dftemp.mod_genre == 'Business']
df_productivity = dftemp[dftemp.mod_genre == 'Productivity']
df_travel = dftemp[dftemp.mod_genre == 'Travel']

df_medical = dftemp[dftemp.mod_genre == 'Medical']
df_weather = dftemp[dftemp.mod_genre == 'Weather']
df_shopping = dftemp[dftemp.mod_genre == 'Shopping']

# %%
dfratios.iloc[15,1] = df_music.downloads.mean()/df_music.all_rating_count.mean()
dfratios.iloc[0,1] = df_socialnetworking.downloads.mean()/df_socialnetworking.all_rating_count.mean()
dfratios.iloc[12,1] = df_news.downloads.mean()/df_news.all_rating_count.mean()
dfratios.iloc[1,1] = df_entertainment.downloads.mean()/df_entertainment.all_rating_count.mean()
dfratios.iloc[4,1] = df_photo.downloads.mean()/df_photo.all_rating_count.mean()
dfratios.iloc[18,1] = df_navigation.downloads.mean()/df_navigation.all_rating_count.mean()
dfratios.iloc[6,1] = df_health.downloads.mean()/df_health.all_rating_count.mean()
dfratios.iloc[16,1] = df_sports.downloads.mean()/df_sports.all_rating_count.mean()
dfratios.iloc[11,1] = df_business.downloads.mean()/df_business.all_rating_count.mean()
dfratios.iloc[9,1] = df_productivity.downloads.mean()/df_productivity.all_rating_count.mean()
dfratios.iloc[13,1] = df_travel.downloads.mean()/df_travel.all_rating_count.mean()
dfratios.iloc[14,1] = df_medical.downloads.mean()/df_medical.all_rating_count.mean()
dfratios.iloc[19,1] = df_weather.downloads.mean()/df_weather.all_rating_count.mean()
dfratios.iloc[2,1] = df_shopping.downloads.mean()/df_shopping.all_rating_count.mean()

# %%
dfratios
# Out:
#              mod_genre         WOM
# 0    Social Networking  139.479387
# 1        Entertainment  249.248083
# 2             Shopping  249.684691
# 3                Games  132.160000
# 4        Photo & Video  266.549835
# 6            Education  324.740000
# 12    Health & Fitness  220.268029
# 16           Lifestyle  287.840000
# 31   Books & Reference  217.470000
# 47        Productivity  187.362254
# 51           Utilities  229.620000
# 66            Business  212.914841
# 80                News  220.308006
# 90              Travel  305.977745
# 98             Medical  308.904129
# 125              Music  223.554220
# 147             Sports  216.963681
# 164            Finance  197.200000
# 220         Navigation  251.110774
# 488            Weather  167.730128

# %%
df_utilities.corr()
# Out:
#                        age  all_rating  all_rating_count  downloads  \
# age               1.000000   -0.228241         -0.000297  -0.000653
# all_rating       -0.228241    1.000000          0.027646   0.005846
# all_rating_count -0.000297    0.027646          1.000000   0.366177
# downloads        -0.000653    0.005846          0.366177   1.000000
# epoch_date       -1.000000    0.228241          0.000297   0.000653
# file_size        -0.149843    0.014050          0.016460   0.013880
# price             0.006003   -0.020124         -0.008000  -0.007655
#
#                   epoch_date  file_size     price
# age                -1.000000  -0.149843  0.006003
# all_rating          0.228241   0.014050 -0.020124
# all_rating_count    0.000297   0.016460 -0.008000
# downloads           0.000653   0.013880 -0.007655
# epoch_date          1.000000   0.149843 -0.006003
# file_size           0.149843   1.000000  0.049813
# price              -0.006003   0.049813  1.000000

# %%
df_books.corr()
# Out:
#                        age  all_rating  all_rating_count  downloads  \
# age               1.000000   -0.229747          0.007607   0.015249
# all_rating       -0.229747    1.000000          0.014633   0.010665
# all_rating_count  0.007607    0.014633          1.000000   0.877376
# downloads         0.015249    0.010665          0.877376   1.000000
# epoch_date       -1.000000    0.229747         -0.007607  -0.015249
# file_size        -0.052103    0.004503         -0.000243  -0.003011
# price             0.123492   -0.079352         -0.009168  -0.015636
#
#                   epoch_date  file_size     price
# age                -1.000000  -0.052103  0.123492
# all_rating          0.229747   0.004503 -0.079352
# all_rating_count   -0.007607  -0.000243 -0.009168
# downloads          -0.015249  -0.003011 -0.015636
# epoch_date          1.000000   0.052103 -0.123492
# file_size           0.052103   1.000000  0.112534
# price              -0.123492   0.112534  1.000000

# %%
df_business.corr()
# Out:
#                        age  all_rating  all_rating_count  downloads  \
# age               1.000000   -0.201753          0.019157   0.033564
# all_rating       -0.201753    1.000000          0.003946  -0.008692
# all_rating_count  0.019157    0.003946          1.000000   0.813162
# downloads         0.033564   -0.008692          0.813162   1.000000
# epoch_date       -1.000000    0.201753         -0.019157  -0.033564
# file_size        -0.104922    0.016248          0.008243   0.006491
# price             0.047937   -0.048249          0.010018  -0.004607
#
#                   epoch_date  file_size     price
# age                -1.000000  -0.104922  0.047937
# all_rating          0.201753   0.016248 -0.048249
# all_rating_count   -0.019157   0.008243  0.010018
# downloads          -0.033564   0.006491 -0.004607
# epoch_date          1.000000   0.104922 -0.047937
# file_size           0.104922   1.000000  0.021312
# price              -0.047937   0.021312  1.000000

# %%
df_productivity.corr()
# Out:
#                        age  all_rating  all_rating_count  downloads  \
# age               1.000000   -0.241789         -0.008543  -0.004698
# all_rating       -0.241789    1.000000          0.028996   0.026056
# all_rating_count -0.008543    0.028996          1.000000   0.781693
# downloads        -0.004698    0.026056          0.781693   1.000000
# epoch_date       -1.000000    0.241789          0.008543   0.004698
# file_size        -0.139378    0.009512          0.022340   0.022197
# price             0.013149   -0.031655         -0.009056  -0.014021
#
#                   epoch_date  file_size     price
# age                -1.000000  -0.139378  0.013149
# all_rating          0.241789   0.009512 -0.031655
# all_rating_count    0.008543   0.022340 -0.009056
# downloads           0.004698   0.022197 -0.014021
# epoch_date          1.000000   0.139378 -0.013149
# file_size           0.139378   1.000000  0.042635
# price              -0.013149   0.042635  1.000000

# %%
dfratios.to_csv("alldata_genrewom.csv")

# %%
dfratios["mod_genre"]
# Out:
# 0      Social Networking
# 1          Entertainment
# 2               Shopping
# 3                  Games
# 4          Photo & Video
# 6              Education
# 12      Health & Fitness
# 16             Lifestyle
# 31     Books & Reference
# 47          Productivity
# 51             Utilities
# 66              Business
# 80                  News
# 90                Travel
# 98               Medical
# 125                Music
# 147               Sports
# 164              Finance
# 220           Navigation
# 488              Weather
# Name: mod_genre, dtype: object

# %%
dftemp.to_csv(path_or_buf="clean_android_genre.csv", header=True, index=False, encoding="utf-8")

# %%
df_utilities.to_csv(path_or_buf="android_utilities.csv", header=True, index=False, encoding="utf-8")
